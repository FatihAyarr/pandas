# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s[3]
# Out:
# nan

# %%
dates = pd.date_range("20190101", periods=6, freq="D")
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2019-01-01 -0.885171 -1.099876  0.232344 -1.304212
# 2019-01-02  0.647508  1.241694 -0.203159  0.202286
# 2019-01-03 -1.773460 -0.484439  0.916447  0.629958
# 2019-01-04  0.580120  1.131273 -1.450487  0.943619
# 2019-01-05 -1.355809  1.365877  0.546615 -0.223117
# 2019-01-06 -2.454679  0.203025  0.083072  0.753986

# %%
df2 = pd.DataFrame(
    {
    "A": [1,6,44,7526],
    "B": pd.Timestamp("20130102"),
    "C": pd.Series(1, index=list(range(4)), dtype="float32"),
    "D": np.array([3] * 4),
    "E": pd.Categorical(["test", "train", "tesdfhgfjt", "train"]),
    "F": "foo",
    }
)

df2
# Out:
#       A          B    C  D           E    F
# 0     1 2013-01-02  1.0  3        test  foo
# 1     6 2013-01-02  1.0  3       train  foo
# 2    44 2013-01-02  1.0  3  tesdfhgfjt  foo
# 3  7526 2013-01-02  1.0  3       train  foo

# %%
type(float(np.array([3] * 4)[0]))
# Out:
# float

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2019-01-01 -0.885171 -1.099876  0.232344 -1.304212
# 2019-01-02  0.647508  1.241694 -0.203159  0.202286

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2019-01-05 -1.355809  1.365877  0.546615 -0.223117
# 2019-01-06 -2.454679  0.203025  0.083072  0.753986

# %%
for i in df.index:
    print((str(i)[0:4]))
# Out:
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.873582  0.392926  0.020805  0.167087
# std    1.262481  1.024352  0.817574  0.834257
# min   -2.454679 -1.099876 -1.450487 -1.304212
# 25%   -1.669048 -0.312573 -0.131601 -0.116766
# 50%   -1.120490  0.667149  0.157708  0.416122
# 75%    0.213797  1.214089  0.468047  0.722979
# max    0.647508  1.365877  0.916447  0.943619

# %%
max_liste = []
for i in df.max():
    max_liste.append(i)
max(max_liste)
# Out:
# 1.3658765509572055

# %%
df.T
# Out:
#    2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  2019-01-06
# A   -0.885171    0.647508   -1.773460    0.580120   -1.355809   -2.454679
# B   -1.099876    1.241694   -0.484439    1.131273    1.365877    0.203025
# C    0.232344   -0.203159    0.916447   -1.450487    0.546615    0.083072
# D   -1.304212    0.202286    0.629958    0.943619   -0.223117    0.753986

# %%
df2 = df.T
df2
# Out:
#    2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  2019-01-06
# A   -0.885171    0.647508   -1.773460    0.580120   -1.355809   -2.454679
# B   -1.099876    1.241694   -0.484439    1.131273    1.365877    0.203025
# C    0.232344   -0.203159    0.916447   -1.450487    0.546615    0.083072
# D   -1.304212    0.202286    0.629958    0.943619   -0.223117    0.753986

# %%
df3 = pd.read_csv("chronic_kidney_disease.csv")
df3.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0       ?    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0       ?    normal  notpresent  notpresent    ?  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000    ?   no   no  no  good   no   no   ckd
# 2  31  7500    ?   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
df3.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'class'],
#       dtype='object')

# %%
df3.shape
# Out:
# (400, 25)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
# age      400 non-null object
# bp       400 non-null object
# sg       400 non-null object
# al       400 non-null object
# su       400 non-null object
# rbc      400 non-null object
# pc       400 non-null object
# pcc      400 non-null object
# ba       400 non-null object
# bgr      400 non-null object
# bu       400 non-null object
# sc       400 non-null object
# sod      400 non-null object
# pot      400 non-null object
# hemo     400 non-null object
# pcv      400 non-null object
# wc       400 non-null object
# rc       400 non-null object
# htn      400 non-null object
# dm       400 non-null object
# cad      400 non-null object
# appet    400 non-null object
# pe       400 non-null object
# ane      400 non-null object
# class    400 non-null object
# dtypes: object(25)
# memory usage: 78.2+ KB

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df3["age"])
# Out:
# pandas.core.series.Series

# %%
#df3.sort_values(by="age",ascending=False).head()

# %%
df3["age"].head()
# Out:
# 0    48
# 1     7
# 2    62
# 3    48
# 4    51
# Name: age, dtype: object

# %%
df3[0:3]
# Out:
#   age  bp     sg al su     rbc      pc         pcc          ba  bgr  ...  pcv  \
# 0  48  80  1.020  1  0       ?  normal  notpresent  notpresent  121  ...   44
# 1   7  50  1.020  4  0       ?  normal  notpresent  notpresent    ?  ...   38
# 2  62  80  1.010  2  3  normal  normal  notpresent  notpresent  423  ...   31
#
#      wc   rc  htn   dm cad appet  pe  ane class
# 0  7800  5.2  yes  yes  no  good  no   no   ckd
# 1  6000    ?   no   no  no  good  no   no   ckd
# 2  7500    ?   no  yes  no  poor  no  yes   ckd
#
# [3 rows x 25 columns]

# %%
df3.loc[0:10, ["age", "bp"]]
# Out:
#    age   bp
# 0   48   80
# 1    7   50
# 2   62   80
# 3   48   70
# 4   51   80
# 5   60   90
# 6   68   70
# 7   24    ?
# 8   52  100
# 9   53   90
# 10  50   60

# %%
df3.loc[:,["age", "bp"]].head()
# Out:
#   age  bp
# 0  48  80
# 1   7  50
# 2  62  80
# 3  48  70
# 4  51  80

# %%
df3.iloc[3]
# Out:
# age              48
# bp               70
# sg            1.005
# al                4
# su                0
# rbc          normal
# pc         abnormal
# pcc         present
# ba       notpresent
# bgr             117
# bu               56
# sc              3.8
# sod             111
# pot             2.5
# hemo           11.2
# pcv              32
# wc             6700
# rc              3.9
# htn             yes
# dm               no
# cad              no
# appet          poor
# pe              yes
# ane             yes
# class           ckd
# Name: 3, dtype: object

# %%
df3.iloc[5:8]
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 5  60  90  1.015  3  0       ?         ?  notpresent  notpresent   74  ...
# 6  68  70  1.010  0  0       ?    normal  notpresent  notpresent  100  ...
# 7  24   ?  1.015  2  4  normal  abnormal  notpresent  notpresent  410  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe ane class
# 5  39  7800  4.4  yes  yes  no  good  yes  no   ckd
# 6  36     ?    ?   no   no  no  good   no  no   ckd
# 7  44  6900    5   no  yes  no  good  yes  no   ckd
#
# [3 rows x 25 columns]

# %%
df3.iloc[3:8, 0:5]
# Out:
#   age  bp     sg al su
# 3  48  70  1.005  4  0
# 4  51  80  1.010  2  0
# 5  60  90  1.015  3  0
# 6  68  70  1.010  0  0
# 7  24   ?  1.015  2  4

# %%
df3.iloc[[1, 2, 4], [0, 10,12]]
# Out:
#   age  bu sod
# 1   7  18   ?
# 2  62  53   ?
# 4  51  26   ?

# %%
df3.iloc[3:5, :]
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn  dm cad appet   pe  ane class
# 3  32  6700  3.9  yes  no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no  no  no  good   no   no   ckd
#
# [2 rows x 25 columns]

# %%
df3.iloc[:, 1:5].head()
# Out:
#    bp     sg al su
# 0  80  1.020  1  0
# 1  50  1.020  4  0
# 2  80  1.010  2  3
# 3  70  1.005  4  0
# 4  80  1.010  2  0

# %%
df3.iloc[1, 1]
# Out:
# '50'

# %%
df3[df3["class"].isin(["ckd"])].head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0       ?    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0       ?    normal  notpresent  notpresent    ?  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000    ?   no   no  no  good   no   no   ckd
# 2  31  7500    ?   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
df3.replace("?", np.nan,inplace=True)

# %%
df3.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0     NaN    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0     NaN    normal  notpresent  notpresent  NaN  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000  NaN   no   no  no  good   no   no   ckd
# 2  31  7500  NaN   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
# age      391 non-null object
# bp       388 non-null object
# sg       353 non-null object
# al       354 non-null object
# su       351 non-null object
# rbc      248 non-null object
# pc       335 non-null object
# pcc      396 non-null object
# ba       396 non-null object
# bgr      356 non-null object
# bu       381 non-null object
# sc       383 non-null object
# sod      313 non-null object
# pot      312 non-null object
# hemo     348 non-null object
# pcv      329 non-null object
# wc       294 non-null object
# rc       269 non-null object
# htn      398 non-null object
# dm       398 non-null object
# cad      398 non-null object
# appet    399 non-null object
# pe       399 non-null object
# ane      399 non-null object
# class    400 non-null object
# dtypes: object(25)
# memory usage: 78.2+ KB

# %%
df3.dropna().head()
# Out:
#    age  bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3   48  70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9   53  90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11  63  70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14  68  80  1.010  3  2    normal  abnormal     present     present  157
# 20  61  80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
#
#     ...  pcv     wc   rc  htn   dm  cad appet   pe  ane class
# 3   ...   32   6700  3.9  yes   no   no  poor  yes  yes   ckd
# 9   ...   29  12100  3.7  yes  yes   no  poor   no  yes   ckd
# 11  ...   32   4500  3.8  yes  yes   no  poor  yes   no   ckd
# 14  ...   16  11000  2.6  yes  yes  yes  poor  yes   no   ckd
# 20  ...   24   9200  3.2  yes  yes  yes  poor  yes  yes   ckd
#
# [5 rows x 25 columns]

# %%
df3.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0     NaN    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0     NaN    normal  notpresent  notpresent  NaN  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000  NaN   no   no  no  good   no   no   ckd
# 2  31  7500  NaN   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
pd.isna(df3).head()
# Out:
#      age     bp     sg     al     su    rbc     pc    pcc     ba    bgr  \
# 0  False  False  False  False  False   True  False  False  False  False
# 1  False  False  False  False  False   True  False  False  False   True
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#    ...      pcv     wc     rc    htn     dm    cad  appet     pe    ane  class
# 0  ...    False  False  False  False  False  False  False  False  False  False
# 1  ...    False  False   True  False  False  False  False  False  False  False
# 2  ...    False  False   True  False  False  False  False  False  False  False
# 3  ...    False  False  False  False  False  False  False  False  False  False
# 4  ...    False  False  False  False  False  False  False  False  False  False
#
# [5 rows x 25 columns]

# %%
df3.fillna(value=5).head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0       5    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0       5    normal  notpresent  notpresent    5  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000    5   no   no  no  good   no   no   ckd
# 2  31  7500    5   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
df3.head()
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 0  48  80  1.020  1  0     NaN    normal  notpresent  notpresent  121  ...
# 1   7  50  1.020  4  0     NaN    normal  notpresent  notpresent  NaN  ...
# 2  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 3  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 4  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv    wc   rc  htn   dm cad appet   pe  ane class
# 0  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  38  6000  NaN   no   no  no  good   no   no   ckd
# 2  31  7500  NaN   no  yes  no  poor   no  yes   ckd
# 3  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
col_num = ['sg', 'al', 'su','age','bp','bgr','bu','sc','sod','pot','hemo','pcv','wc','rc'] #liste
col_cat = [ 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad','appet', 'pe', 'ane'] #liste

col_num, col_cat
# Out:
# (['sg',
#   'al',
#   'su',
#   'age',
#   'bp',
#   'bgr',
#   'bu',
#   'sc',
#   'sod',
#   'pot',
#   'hemo',
#   'pcv',
#   'wc',
#   'rc'],
#  ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'])

# %%
df_num = df3[col_num]
df_cat = df3[col_cat]

df_num,df_cat
# Out:
# (        sg   al   su age   bp  bgr   bu    sc  sod  pot  hemo  pcv     wc   rc
#  0    1.020    1    0  48   80  121   36   1.2  NaN  NaN  15.4   44   7800  5.2
#  1    1.020    4    0   7   50  NaN   18   0.8  NaN  NaN  11.3   38   6000  NaN
#  2    1.010    2    3  62   80  423   53   1.8  NaN  NaN   9.6   31   7500  NaN
#  3    1.005    4    0  48   70  117   56   3.8  111  2.5  11.2   32   6700  3.9
#  4    1.010    2    0  51   80  106   26   1.4  NaN  NaN  11.6   35   7300  4.6
#  5    1.015    3    0  60   90   74   25   1.1  142  3.2  12.2   39   7800  4.4
#  6    1.010    0    0  68   70  100   54  24.0  104  4.0  12.4   36    NaN  NaN
#  7    1.015    2    4  24  NaN  410   31   1.1  NaN  NaN  12.4   44   6900    5
#  8    1.015    3    0  52  100  138   60   1.9  NaN  NaN  10.8   33   9600  4.0
#  9    1.020    2    0  53   90   70  107   7.2  114  3.7   9.5   29  12100  3.7
#  10   1.010    2    4  50   60  490   55   4.0  NaN  NaN   9.4   28    NaN  NaN
# ...

# %%
df_num = df_num.astype(float)
df_num.head()
# Out:
#       sg   al   su   age    bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.020  1.0  0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN  15.4  44.0
# 1  1.020  4.0  0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN  11.3  38.0
# 2  1.010  2.0  3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN   9.6  31.0
# 3  1.005  4.0  0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4  1.010  2.0  0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN  11.6  35.0
#
#        wc   rc
# 0  7800.0  5.2
# 1  6000.0  NaN
# 2  7500.0  NaN
# 3  6700.0  3.9
# 4  7300.0  4.6

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
# sg      353 non-null float64
# al      354 non-null float64
# su      351 non-null float64
# age     391 non-null float64
# bp      388 non-null float64
# bgr     356 non-null float64
# bu      381 non-null float64
# sc      383 non-null float64
# sod     313 non-null float64
# pot     312 non-null float64
# hemo    348 non-null float64
# pcv     329 non-null float64
# wc      294 non-null float64
# rc      269 non-null float64
# dtypes: float64(14)
# memory usage: 43.8 KB

# %%
df_num2 = df_num.copy()
df_num2.head()
# Out:
#       sg   al   su   age    bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.020  1.0  0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN  15.4  44.0
# 1  1.020  4.0  0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN  11.3  38.0
# 2  1.010  2.0  3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN   9.6  31.0
# 3  1.005  4.0  0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4  1.010  2.0  0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN  11.6  35.0
#
#        wc   rc
# 0  7800.0  5.2
# 1  6000.0  NaN
# 2  7500.0  NaN
# 3  6700.0  3.9
# 4  7300.0  4.6

# %%
df_num2["new"] = df_num2["age"] * 2
df_num2.head()
# Out:
#       sg   al   su   age    bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.020  1.0  0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN  15.4  44.0
# 1  1.020  4.0  0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN  11.3  38.0
# 2  1.010  2.0  3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN   9.6  31.0
# 3  1.005  4.0  0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4  1.010  2.0  0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN  11.6  35.0
#
#        wc   rc    new
# 0  7800.0  5.2   96.0
# 1  6000.0  NaN   14.0
# 2  7500.0  NaN  124.0
# 3  6700.0  3.9   96.0
# 4  7300.0  4.6  102.0

# %%
df_num2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 15 columns):
# sg      353 non-null float64
# al      354 non-null float64
# su      351 non-null float64
# age     391 non-null float64
# bp      388 non-null float64
# bgr     356 non-null float64
# bu      381 non-null float64
# sc      383 non-null float64
# sod     313 non-null float64
# pot     312 non-null float64
# hemo    348 non-null float64
# pcv     329 non-null float64
# wc      294 non-null float64
# rc      269 non-null float64
# new     391 non-null float64
# dtypes: float64(15)
# memory usage: 47.0 KB

# %%
df_num2["bp/age"] = df_num2["bp"]/df_num2["age"]
df_num2.head()
# Out:
#       sg   al   su   age    bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.020  1.0  0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN  15.4  44.0
# 1  1.020  4.0  0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN  11.3  38.0
# 2  1.010  2.0  3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN   9.6  31.0
# 3  1.005  4.0  0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4  1.010  2.0  0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN  11.6  35.0
#
#        wc   rc    new    bp/age
# 0  7800.0  5.2   96.0  1.666667
# 1  6000.0  NaN   14.0  7.142857
# 2  7500.0  NaN  124.0  1.290323
# 3  6700.0  3.9   96.0  1.458333
# 4  7300.0  4.6  102.0  1.568627

# %%
df_num2_renamed = df_num2.rename(columns={
        "sg": "ilk kolon",
        "al": "ikinci KOLON",
        "su": "kolon3"})

df_num2_renamed.head()
# Out:
#    ilk kolon  ikinci KOLON  kolon3   age    bp    bgr    bu   sc    sod  pot  \
# 0      1.020           1.0     0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN
# 1      1.020           4.0     0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN
# 2      1.010           2.0     3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN
# 3      1.005           4.0     0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5
# 4      1.010           2.0     0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN
#
#    hemo   pcv      wc   rc    new    bp/age
# 0  15.4  44.0  7800.0  5.2   96.0  1.666667
# 1  11.3  38.0  6000.0  NaN   14.0  7.142857
# 2   9.6  31.0  7500.0  NaN  124.0  1.290323
# 3  11.2  32.0  6700.0  3.9   96.0  1.458333
# 4  11.6  35.0  7300.0  4.6  102.0  1.568627

# %%
df_num2_renamed.rename(columns=str.lower,inplace=True)
df_num2_renamed.head()
# Out:
#    ilk kolon  ikinci kolon  kolon3   age    bp    bgr    bu   sc    sod  pot  \
# 0      1.020           1.0     0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN
# 1      1.020           4.0     0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN
# 2      1.010           2.0     3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN
# 3      1.005           4.0     0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5
# 4      1.010           2.0     0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN
#
#    hemo   pcv      wc   rc    new    bp/age
# 0  15.4  44.0  7800.0  5.2   96.0  1.666667
# 1  11.3  38.0  6000.0  NaN   14.0  7.142857
# 2   9.6  31.0  7500.0  NaN  124.0  1.290323
# 3  11.2  32.0  6700.0  3.9   96.0  1.458333
# 4  11.6  35.0  7300.0  4.6  102.0  1.568627

# %%
df_num2_renamed.rename(columns=str.upper,inplace=True)
df_num2_renamed.head()
# Out:
#    ILK KOLON  IKINCI KOLON  KOLON3   AGE    BP    BGR    BU   SC    SOD  POT  \
# 0      1.020           1.0     0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN
# 1      1.020           4.0     0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN
# 2      1.010           2.0     3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN
# 3      1.005           4.0     0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5
# 4      1.010           2.0     0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN
#
#    HEMO   PCV      WC   RC    NEW    BP/AGE
# 0  15.4  44.0  7800.0  5.2   96.0  1.666667
# 1  11.3  38.0  6000.0  NaN   14.0  7.142857
# 2   9.6  31.0  7500.0  NaN  124.0  1.290323
# 3  11.2  32.0  6700.0  3.9   96.0  1.458333
# 4  11.6  35.0  7300.0  4.6  102.0  1.568627

# %%
df_num.head()
# Out:
#       sg   al   su   age    bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.020  1.0  0.0  48.0  80.0  121.0  36.0  1.2    NaN  NaN  15.4  44.0
# 1  1.020  4.0  0.0   7.0  50.0    NaN  18.0  0.8    NaN  NaN  11.3  38.0
# 2  1.010  2.0  3.0  62.0  80.0  423.0  53.0  1.8    NaN  NaN   9.6  31.0
# 3  1.005  4.0  0.0  48.0  70.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4  1.010  2.0  0.0  51.0  80.0  106.0  26.0  1.4    NaN  NaN  11.6  35.0
#
#        wc   rc
# 0  7800.0  5.2
# 1  6000.0  NaN
# 2  7500.0  NaN
# 3  6700.0  3.9
# 4  7300.0  4.6

# %%
df_num.mean()
# Out:
# sg         1.017408
# al         1.016949
# su         0.450142
# age       51.483376
# bp        76.469072
# bgr      148.036517
# bu        57.425722
# sc         3.072454
# sod      137.528754
# pot        4.627244
# hemo      12.526437
# pcv       38.884498
# wc      8406.122449
# rc         4.707435
# dtype: float64

# %%
df_num["age"].mean()
# Out:
# 51.48337595907928

# %%
df_num[["bp","bgr"]].mean()
# Out:
# bp      76.469072
# bgr    148.036517
# dtype: float64

# %%
df_num.mean(1).head()
# Out:
# 0    679.401667
# 1    613.012000
# 2    742.400909
# 3    511.457500
# 4    634.884167
# dtype: float64

# %%
df_num.std()
# Out:
# sg         0.005717
# al         1.352679
# su         1.099191
# age       17.169714
# bp        13.683637
# bgr       79.281714
# bu        50.503006
# sc         5.741126
# sod       10.408752
# pot        3.193904
# hemo       2.912587
# pcv        8.990105
# wc      2944.474190
# rc         1.025323
# dtype: float64

# %%
df_num.std(1).head()
# Out:
# 0    2242.721666
# 1    1892.870403
# 2    2244.555685
# 3    1781.643785
# 4    2099.250209
# dtype: float64

# %%
df_num["age"].std()
# Out:
# 17.16971408926224

# %%
df_num.mode()
# Out:
#      sg   al   su   age    bp   bgr    bu   sc    sod  pot  hemo   pcv  \
# 0  1.02  0.0  0.0  60.0  80.0  99.0  46.0  1.2  135.0  3.5  15.0  41.0
# 1   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN    NaN  5.0   NaN  52.0
#
#        wc   rc
# 0  9800.0  5.2
# 1     NaN  NaN

# %%
df_cat.mode()
# Out:
#       rbc      pc         pcc          ba htn  dm cad appet  pe ane
# 0  normal  normal  notpresent  notpresent  no  no  no  good  no  no

# %%
df_num.median()
# Out:
# sg         1.02
# al         0.00
# su         0.00
# age       55.00
# bp        80.00
# bgr      121.00
# bu        42.00
# sc         1.30
# sod      138.00
# pot        4.40
# hemo      12.65
# pcv       40.00
# wc      8000.00
# rc         4.80
# dtype: float64

# %%
df_cat.median()
# Out:
# Series([], dtype: float64)

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
# rbc      248 non-null object
# pc       335 non-null object
# pcc      396 non-null object
# ba       396 non-null object
# htn      398 non-null object
# dm       398 non-null object
# cad      398 non-null object
# appet    399 non-null object
# pe       399 non-null object
# ane      399 non-null object
# dtypes: object(10)
# memory usage: 31.3+ KB

# %%
df_num.head()
# Out:
#       sg   al   su   age          bp         bgr     bu    sc         sod  \
# 0  1.020  1.0  0.0  48.0   80.000000  121.000000   36.0   1.2  137.528754
# 1  1.020  4.0  0.0   7.0   50.000000  148.036517   18.0   0.8  137.528754
# 2  1.010  2.0  3.0  62.0   80.000000  423.000000   53.0   1.8  137.528754
# 3  1.005  4.0  0.0  48.0   70.000000  117.000000   56.0   3.8  111.000000
# 4  1.010  2.0  0.0  51.0   80.000000  106.000000   26.0   1.4  137.528754
# 5  1.015  3.0  0.0  60.0   90.000000   74.000000   25.0   1.1  142.000000
# 6  1.010  0.0  0.0  68.0   70.000000  100.000000   54.0  24.0  104.000000
# 7  1.015  2.0  4.0  24.0   76.469072  410.000000   31.0   1.1  137.528754
# 8  1.015  3.0  0.0  52.0  100.000000  138.000000   60.0   1.9  137.528754
# 9  1.020  2.0  0.0  53.0   90.000000   70.000000  107.0   7.2  114.000000
#
#         pot  hemo   pcv            wc        rc
# 0  4.627244  15.4  44.0   7800.000000  5.200000
# 1  4.627244  11.3  38.0   6000.000000  4.707435
# ...

# %%
for i in df_num:
    if df_num[i].isna().sum()>0:
        df_num[i].fillna(df_num[i].mean(),inplace=True)

df_num.head()
# Out:
#       sg   al   su   age    bp         bgr    bu   sc         sod       pot  \
# 0  1.020  1.0  0.0  48.0  80.0  121.000000  36.0  1.2  137.528754  4.627244
# 1  1.020  4.0  0.0   7.0  50.0  148.036517  18.0  0.8  137.528754  4.627244
# 2  1.010  2.0  3.0  62.0  80.0  423.000000  53.0  1.8  137.528754  4.627244
# 3  1.005  4.0  0.0  48.0  70.0  117.000000  56.0  3.8  111.000000  2.500000
# 4  1.010  2.0  0.0  51.0  80.0  106.000000  26.0  1.4  137.528754  4.627244
#
#    hemo   pcv      wc        rc
# 0  15.4  44.0  7800.0  5.200000
# 1  11.3  38.0  6000.0  4.707435
# 2   9.6  31.0  7500.0  4.707435
# 3  11.2  32.0  6700.0  3.900000
# 4  11.6  35.0  7300.0  4.600000

# %%
df_cat.head(10)
# Out:
#         rbc        pc         pcc          ba  htn   dm cad appet   pe  ane
# 0       NaN    normal  notpresent  notpresent  yes  yes  no  good   no   no
# 1       NaN    normal  notpresent  notpresent   no   no  no  good   no   no
# 2    normal    normal  notpresent  notpresent   no  yes  no  poor   no  yes
# 3    normal  abnormal     present  notpresent  yes   no  no  poor  yes  yes
# 4    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 5       NaN       NaN  notpresent  notpresent  yes  yes  no  good  yes   no
# 6       NaN    normal  notpresent  notpresent   no   no  no  good   no   no
# 7    normal  abnormal  notpresent  notpresent   no  yes  no  good  yes   no
# 8    normal  abnormal     present  notpresent  yes  yes  no  good   no  yes
# 9  abnormal  abnormal     present  notpresent  yes  yes  no  poor   no  yes

# %%
for b in df_cat:
    if df_cat[b].isna().sum()>0:
        df_cat[b].fillna(df_cat[b].mode()[0],inplace=True)

df_cat.head(10)
# Out:
#         rbc        pc         pcc          ba  htn   dm cad appet   pe  ane
# 0    normal    normal  notpresent  notpresent  yes  yes  no  good   no   no
# 1    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 2    normal    normal  notpresent  notpresent   no  yes  no  poor   no  yes
# 3    normal  abnormal     present  notpresent  yes   no  no  poor  yes  yes
# 4    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 5    normal    normal  notpresent  notpresent  yes  yes  no  good  yes   no
# 6    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 7    normal  abnormal  notpresent  notpresent   no  yes  no  good  yes   no
# 8    normal  abnormal     present  notpresent  yes  yes  no  good   no  yes
# 9  abnormal  abnormal     present  notpresent  yes  yes  no  poor   no  yes

# %%
df4 = pd.concat([df_num,df_cat],axis=1)
df4.head(10)
# Out:
#       sg   al   su   age          bp         bgr     bu    sc         sod  \
# 0  1.020  1.0  0.0  48.0   80.000000  121.000000   36.0   1.2  137.528754
# 1  1.020  4.0  0.0   7.0   50.000000  148.036517   18.0   0.8  137.528754
# 2  1.010  2.0  3.0  62.0   80.000000  423.000000   53.0   1.8  137.528754
# 3  1.005  4.0  0.0  48.0   70.000000  117.000000   56.0   3.8  111.000000
# 4  1.010  2.0  0.0  51.0   80.000000  106.000000   26.0   1.4  137.528754
# 5  1.015  3.0  0.0  60.0   90.000000   74.000000   25.0   1.1  142.000000
# 6  1.010  0.0  0.0  68.0   70.000000  100.000000   54.0  24.0  104.000000
# 7  1.015  2.0  4.0  24.0   76.469072  410.000000   31.0   1.1  137.528754
# 8  1.015  3.0  0.0  52.0  100.000000  138.000000   60.0   1.9  137.528754
# 9  1.020  2.0  0.0  53.0   90.000000   70.000000  107.0   7.2  114.000000
#
#         pot ...        rbc        pc         pcc          ba  htn   dm cad  \
# 0  4.627244 ...     normal    normal  notpresent  notpresent  yes  yes  no
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
# sg       400 non-null float64
# al       400 non-null float64
# su       400 non-null float64
# age      400 non-null float64
# bp       400 non-null float64
# bgr      400 non-null float64
# bu       400 non-null float64
# sc       400 non-null float64
# sod      400 non-null float64
# pot      400 non-null float64
# hemo     400 non-null float64
# pcv      400 non-null float64
# wc       400 non-null float64
# rc       400 non-null float64
# rbc      400 non-null object
# pc       400 non-null object
# pcc      400 non-null object
# ba       400 non-null object
# htn      400 non-null object
# dm       400 non-null object
# cad      400 non-null object
# appet    400 non-null object
# pe       400 non-null object
# ane      400 non-null object
# dtypes: float64(14), object(10)
# memory usage: 75.1+ KB

# %%
df4.groupby("age").mean().head(10)
# Out:
#             sg        al        su         bp         bgr         bu  \
# age
# 2.0   1.010000  3.000000  0.000000  76.469072  148.036517  57.425722
# 3.0   1.010000  2.000000  0.000000  76.469072  148.036517  22.000000
# 4.0   1.020000  1.000000  0.000000  76.469072   99.000000  23.000000
# 5.0   1.012500  0.500000  0.000000  63.234536  148.036517  20.500000
# 6.0   1.010000  4.000000  0.000000  60.000000   94.000000  67.000000
# 7.0   1.020000  4.000000  0.000000  50.000000  148.036517  18.000000
# 8.0   1.020803  2.672316  0.150047  62.156357  102.012172  46.333333
# 11.0  1.010000  3.000000  0.000000  80.000000  148.036517  17.000000
# 12.0  1.017500  1.500000  0.000000  70.000000  124.018258  38.500000
# 14.0  1.015000  0.000000  0.000000  76.469072  192.000000  15.000000
#
#             sc         sod       pot       hemo        pcv            wc  \
# age
# 2.0   3.072454  137.528754  4.627244  12.526437  38.884498   8406.122449
# ...

# %%
df4.groupby("pc").mean().head()
# Out:
#                 sg        al        su        age         bp         bgr  \
# pc
# abnormal  1.013584  2.421053  0.808555  55.052194  80.828133  188.480411
# normal    1.018305  0.687592  0.366070  50.646246  75.446576  138.549677
#
#                  bu        sc         sod       pot       hemo        pcv  \
# pc
# abnormal  92.393121  4.901544  134.238965  5.550350  10.221552  31.848664
# normal    49.223492  2.643409  138.300433  4.410712  13.067089  40.534879
#
#                    wc        rc
# pc
# abnormal  8967.481203  4.043333
# normal    8274.445704  4.863212

# %%
df4.groupby("pc")["age"].mean()
# Out:
# pc
# abnormal    55.052194
# normal      50.646246
# Name: age, dtype: float64

# %%
df4.groupby("pcc").sum()
# Out:
#                     sg          al         su           age            bp  \
# pcc
# notpresent  364.423173  301.779661  142.05698  18100.350384  27277.628866
# present      42.540000  105.000000   38.00000   2493.000000   3310.000000
#
#                      bgr            bu           sc           sod  \
# pcc
# notpresent  51187.424157  19445.288714  1065.581723  49395.512780
# present      8027.182584   3525.000000   163.400000   5615.988818
#
#                     pot         hemo           pcv            wc           rc
# pcc
# notpresent  1658.734295  4576.195402  14214.376900  2.958882e+06  1712.840149
# present      192.163141   434.379310   1339.422492  4.035673e+05   170.133829

# %%
df4.groupby(["pc","pcc"]).mean()
# Out:
#                            sg        al        su        age         bp  \
# pc       pcc
# abnormal notpresent  1.014591  2.395349  0.731399  52.255041  82.161352
#          present     1.012273  2.454545  0.909091  58.696970  79.090909
# normal   notpresent  1.018399  0.631047  0.351133  50.328202  75.379971
#          present     1.015000  2.666667  0.888889  61.777778  77.777778
#
#                             bgr          bu        sc         sod       pot  \
# pc       pcc
# abnormal notpresent  188.961131  100.578539  5.670171  134.879449  6.341853
#          present     187.854018   81.727273  3.900000  133.404395  4.518998
# normal   notpresent  136.705065   48.001307  2.608776  138.399036  4.400110
#          present     203.111111   92.000000  3.855556  134.849308  4.781802
#
#                           hemo        pcv            wc        rc
# pc       pcc
# abnormal notpresent  10.248490  32.347918   8106.786901  4.093291
# ...

# %%
df4.groupby(["pc","pcc"])["age"].mean()
# Out:
# pc        pcc
# abnormal  notpresent    52.255041
#           present       58.696970
# normal    notpresent    50.328202
#           present       61.777778
# Name: age, dtype: float64

# %%
df4.groupby(["pc","pcc","dm"])["age"].mean()
# Out:
# pc        pcc         dm
# abnormal  notpresent  no      46.348338
#                       yes     57.391304
#           present     no      54.000000
#                       yes     62.611111
# normal    notpresent   yes    51.483376
#                       no      46.535334
#                       yes     59.903934
#           present     no      54.333333
#                       yes     65.500000
# Name: age, dtype: float64

# %%
df4["pc"].value_counts()
# Out:
# normal      324
# abnormal     76
# Name: pc, dtype: int64

# %%
df4["age"].value_counts().head()
# Out:
# 60.0    19
# 65.0    17
# 48.0    12
# 50.0    12
# 55.0    12
# Name: age, dtype: int64

# %%
df4.groupby("age")["age"].count().head()
# Out:
# age
# 2.0    1
# 3.0    1
# 4.0    1
# 5.0    2
# 6.0    1
# Name: age, dtype: int64

# %%
df4.sort_values(by="age").head()
# Out:
#         sg   al   su  age         bp         bgr         bu        sc  \
# 215  1.010  3.0  0.0  2.0  76.469072  148.036517  57.425722  3.072454
# 187  1.010  2.0  0.0  3.0  76.469072  148.036517  22.000000  0.700000
# 185  1.020  1.0  0.0  4.0  76.469072   99.000000  23.000000  0.600000
# 75   1.015  1.0  0.0  5.0  76.469072  148.036517  16.000000  0.700000
# 131  1.010  0.0  0.0  5.0  50.000000  148.036517  25.000000  0.600000
#
#             sod       pot ...      rbc        pc         pcc          ba htn  \
# 215  137.528754  4.627244 ...   normal  abnormal  notpresent  notpresent  no
# 187  137.528754  4.627244 ...   normal    normal  notpresent  notpresent  no
# 185  138.000000  4.400000 ...   normal    normal  notpresent  notpresent  no
# 75   138.000000  3.200000 ...   normal    normal  notpresent  notpresent  no
# 131  137.528754  4.627244 ...   normal    normal  notpresent  notpresent  no
#
#      dm cad appet   pe  ane
# 215  no  no  good  yes   no
# ...

# %%
df4.sort_values(by="bgr").head()
# Out:
#         sg   al   su   age    bp   bgr     bu   sc    sod  pot ...        rbc  \
# 173  1.015  1.0  0.0  17.0  70.0  22.0    1.5  7.3  145.0  2.8 ...   abnormal
# 288  1.025  0.0  0.0  56.0  70.0  70.0   46.0  1.2  135.0  4.9 ...     normal
# 48   1.005  0.0  0.0  73.0  70.0  70.0   32.0  0.9  125.0  4.0 ...     normal
# 9    1.020  2.0  0.0  53.0  90.0  70.0  107.0  7.2  114.0  3.7 ...   abnormal
# 361  1.020  0.0  0.0  29.0  80.0  70.0   16.0  0.7  138.0  3.5 ...     normal
#
#            pc         pcc          ba  htn   dm cad appet   pe  ane
# 173    normal  notpresent  notpresent   no   no  no  good   no   no
# 288    normal  notpresent  notpresent   no   no  no  good   no   no
# 48     normal  notpresent  notpresent  yes  yes  no  good  yes   no
# 9    abnormal     present  notpresent  yes  yes  no  poor   no  yes
# 361    normal  notpresent  notpresent   no   no  no  good   no   no
#
# [5 rows x 24 columns]

# %%
df4.sort_values(by="age",ascending=False).head()
# Out:
#            sg        al        su   age    bp         bgr         bu  \
# 200  1.025000  1.000000  0.000000  90.0  90.0  139.000000  89.000000
# 171  1.020000  3.000000  0.000000  83.0  70.0  102.000000  60.000000
# 39   1.010000  2.000000  2.000000  82.0  80.0  140.000000  70.000000
# 160  1.017408  1.016949  0.450142  81.0  60.0  148.000000  39.000000
# 312  1.020000  0.000000  0.000000  80.0  70.0  148.036517  57.425722
#
#            sc    sod  pot ...      rbc      pc         pcc          ba  htn  \
# 200  3.000000  140.0  4.1 ...   normal  normal  notpresent  notpresent  yes
# 171  2.600000  115.0  5.7 ...   normal  normal  notpresent  notpresent  yes
# 39   3.400000  136.0  4.2 ...   normal  normal  notpresent  notpresent  yes
# 160  2.100000  147.0  4.2 ...   normal  normal  notpresent  notpresent  yes
# 312  3.072454  135.0  4.1 ...   normal  normal  notpresent  notpresent   no
#
#       dm  cad appet   pe  ane
# 200  yes   no  good   no   no
# 171   no   no  poor   no  yes
# ...

# %%
df4.sort_values(by=['su', 'age'], ascending=False).head()
# Out:
#         sg   al   su   age    bp         bgr     bu   sc         sod  \
# 170  1.015  2.0  5.0  66.0  70.0  447.000000   41.0  1.7  131.000000
# 53   1.015  0.0  5.0  62.0  80.0  246.000000   24.0  1.0  137.528754
# 225  1.010  3.0  5.0  60.0  90.0  490.000000   95.0  2.7  131.000000
# 56   1.015  3.0  4.0  76.0  70.0  148.036517  164.0  9.7  131.000000
# 180  1.010  1.0  4.0  73.0  90.0  234.000000   56.0  1.9  137.528754
#
#           pot ...       rbc        pc         pcc          ba  htn   dm  cad  \
# 170  3.900000 ...    normal    normal  notpresent  notpresent  yes  yes   no
# 53   4.627244 ...    normal    normal  notpresent  notpresent  yes  yes   no
# 225  3.800000 ...  abnormal    normal  notpresent     present  yes  yes   no
# 56   4.400000 ...    normal  abnormal     present  notpresent  yes  yes  yes
# 180  4.627244 ...  abnormal  abnormal     present  notpresent   no  yes   no
#
#     appet   pe ane
# 170  good   no  no
# 53   good   no  no
# 225  good   no  no
# ...

# %%
df4.sort_values(by=['age', 'su'], ascending=True).head()
# Out:
#         sg   al   su  age         bp         bgr         bu        sc  \
# 215  1.010  3.0  0.0  2.0  76.469072  148.036517  57.425722  3.072454
# 187  1.010  2.0  0.0  3.0  76.469072  148.036517  22.000000  0.700000
# 185  1.020  1.0  0.0  4.0  76.469072   99.000000  23.000000  0.600000
# 75   1.015  1.0  0.0  5.0  76.469072  148.036517  16.000000  0.700000
# 131  1.010  0.0  0.0  5.0  50.000000  148.036517  25.000000  0.600000
#
#             sod       pot ...      rbc        pc         pcc          ba htn  \
# 215  137.528754  4.627244 ...   normal  abnormal  notpresent  notpresent  no
# 187  137.528754  4.627244 ...   normal    normal  notpresent  notpresent  no
# 185  138.000000  4.400000 ...   normal    normal  notpresent  notpresent  no
# 75   138.000000  3.200000 ...   normal    normal  notpresent  notpresent  no
# 131  137.528754  4.627244 ...   normal    normal  notpresent  notpresent  no
#
#      dm cad appet   pe  ane
# 215  no  no  good  yes   no
# ...

# %%
df5 = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df5
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df5.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
df5.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df5.shape
# Out:
# (1470, 35)

# %%
col_num2 = ["Age",
"DailyRate",
"DistanceFromHome",
"Education",
"EmployeeCount",
"EmployeeNumber",
"EnvironmentSatisfaction",
"HourlyRate",
"JobInvolvement",
"JobLevel",
"JobSatisfaction",
"MonthlyIncome",
"MonthlyRate",
"NumCompaniesWorked",
"PercentSalaryHike",
"PerformanceRating",
"RelationshipSatisfaction",
"StandardHours",
"StockOptionLevel",
"TotalWorkingYears",
"TrainingTimesLastYear",
"WorkLifeBalance",
"YearsAtCompany",
"YearsInCurrentRole",
"YearsSinceLastPromotion",
"YearsWithCurrManager"] #liste

col_cat2 = ["BusinessTravel","Department","EducationField","Gender","JobRole","MaritalStatus","Over18","OverTime"] #liste

df_num5 = df5[col_num2]
df_cat5 = df5[col_cat2]

# %%
df_num5.head(10)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
# 5   32       1005                 2          2              1               8
# 6   59       1324                 3          3              1              10
# 7   30       1358                24          1              1              11
# 8   38        216                23          3              1              12
# 9   36       1299                27          3              1              13
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df_cat5.head(10)
# Out:
#       BusinessTravel              Department EducationField  Gender  \
# 0      Travel_Rarely                   Sales  Life Sciences  Female
# 1  Travel_Frequently  Research & Development  Life Sciences    Male
# 2      Travel_Rarely  Research & Development          Other    Male
# 3  Travel_Frequently  Research & Development  Life Sciences  Female
# 4      Travel_Rarely  Research & Development        Medical    Male
# 5  Travel_Frequently  Research & Development  Life Sciences    Male
# 6      Travel_Rarely  Research & Development        Medical  Female
# 7      Travel_Rarely  Research & Development  Life Sciences    Male
# 8  Travel_Frequently  Research & Development  Life Sciences    Male
# 9      Travel_Rarely  Research & Development        Medical    Male
#
#                      JobRole MaritalStatus Over18 OverTime
# 0            Sales Executive        Single      Y      Yes
# 1         Research Scientist       Married      Y       No
# ...

# %%
df_num5.groupby("Age").mean().head()
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# Age
# 18   747.625000          6.125000   2.500000            1.0     1053.625000
# 19   548.444444         10.555556   2.111111            1.0      675.666667
# 20   819.454545          7.090909   2.636364            1.0     1021.000000
# 21   762.846154          9.076923   1.615385            1.0      951.538462
# 22   806.937500          8.437500   1.812500            1.0      869.250000
#
#      EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# Age
# 18                  2.750000   68.125000        2.875000     1.000
# 19                  2.444444   63.555556        2.444444     1.000
# 20                  3.181818   61.909091        2.636364     1.000
# 21                  2.692308   67.307692        2.692308     1.000
# 22                  2.812500   69.812500        2.750000     1.125
#
#      JobSatisfaction          ...           RelationshipSatisfaction  \
# ...

# %%
df_cat5.groupby("BusinessTravel").sum()
# Out:
#                                                           Department  \
# BusinessTravel
# Non-Travel         Research & DevelopmentResearch & DevelopmentSa...
# Travel_Frequently  Research & DevelopmentResearch & DevelopmentRe...
# Travel_Rarely      SalesResearch & DevelopmentResearch & Developm...
#
#                                                       EducationField  \
# BusinessTravel
# Non-Travel         MedicalOtherMarketingMedicalMedicalMedicalMedi...
# Travel_Frequently  Life SciencesLife SciencesLife SciencesLife Sc...
# Travel_Rarely      Life SciencesOtherMedicalMedicalLife SciencesM...
#
#                                                               Gender  \
# BusinessTravel
# Non-Travel         MaleFemaleMaleMaleFemaleMaleMaleMaleFemaleFema...
# Travel_Frequently  MaleFemaleMaleMaleFemaleFemaleMaleFemaleMaleFe...
# Travel_Rarely      FemaleMaleMaleFemaleMaleMaleMaleFemaleMaleMale...
#
#                                                              JobRole  \
# ...

# %%
df_num5.groupby("Education")["Age"].mean()
# Out:
# Education
# 1    32.164706
# 2    36.861702
# 3    36.479021
# 4    39.281407
# 5    39.895833
# Name: Age, dtype: float64
